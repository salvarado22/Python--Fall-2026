# %%
score = 85
if score >= 60: print('You passed!')
# Out:
# You passed!

# %%
# if Condition:
    #code runs only when CONDITION is True
    #indentended 4 spaces - same rule as loops!
    # if a condition is false the body is fully skipped
    # : colon is required

# %%
#if / else TWO PATHS

score = 45
if score >= 60:
    print('You passed')
else: 
    print('Please retake')

#Only ONE branch runs:
#score =85 --> 85>=60 is TRUe
#          --> 'You passed!'
# Out:
# Please retake

# %%
temperature = 72 
if temperature > 80:
    print('Hot - wear shorts')
else:
    print('Cool- bring a jacket')
# Out:
# Cool- bring a jacket

# %%
score = 82
if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else: 
    grade = 'F'

print(f'Grade: {grade}') 

#Python checks TOP to BOTTOM and STOPS at the FIRST true condition
#important conditions should be on top
# Out:
# Grade: B

# %%
age = 12
has_id = True

#and - BOTH must be Trues
if age >= 18 and has_id:
    print('Entry allowed')

#or - AT LEAST ONE must be True
if age < 18 or not has_id:
    print('Entry denied')

#not - flips True to False, False to True
if not has_id:
    print('No ID - denied')
# Out:
# Entry denied

# %%
#1. Grade classifier - chained elif

def classify_grade(score):
    if score >= 90:   return 'A - Excellent!'
    elif score >= 80: return 'B- Good'
    elif score >= 70: return 'C- Average'
    elif score >= 60: return 'D- Needs work'
    else:             return 'F- Please retake'
print(classify_grade(85))

#Login validator - and operator
username = 'admin'
password = 'secret123'
if username == 'admin' and password == 'secret123':
    print('Login successful!')
else: 
    print('Invalid credentials')

#3. Temperature advisor - nested ifs
temp = 72
if temp > 90:
    print('Very hot - stay hydrated')
elif temp > 70:
    print('Nice - perfect weather')
elif temp > 50:
    print('Cool - bring a light jacket')
else:
    print('Cold - wear a coat')
# Out:
# B- Good
# Login successful!
# Nice - perfect weather

# %%
age = 20
has_ticket = True
is_vip = False

if age >= 18:
    print('Age check: OK')
    if has_ticket:
        print('Has ticket: OK')
        if is_vip:
            print('VIP neat!')
        else: print('General seat')
    else:
        print('No ticket - denied')
else:
    print('Under 18 - denied')
# Out:
# Age check: OK
# Has ticket: OK
# General seat

# %%
#PCEP Drill
x = 15
if x >10:
    print('big')
elif x > 5:
    print('medium')
else:
    print('small')
# Out:
# big

# %%
#PCEP Drill
a = 5
b = 10
if a > b:
    print('A wins')
elif a==b:
    print('Tie')
else: 
    print('B wins')
# Out:
# B wins

# %%
n = 7
if n % 2 == 0:    print('even')
else:             print('odd')
# Out:
# odd

# %%
#Precedence in Practice- Trace

x = 5
y = 3
z = 10

#Example 1: and before or
result = x > 3 or y > 5 and z > 8
#Python reads: x>3 or (y>5 and z>8)
#Step 1: y>5 and z>8 = False and True = False
#Step 2: x>3 or False = True or False = True
print(result)

#Example 2: not before and
result2 = not x > 10 and y >1
#Python reads: (not x>10) and y>1
#Step 1: not x>10 = not False = True
#Step 2: True and y>1 = True and True = True
print(result2)

#Use parentheses to make intent CLEAR:
result3 = (x > 3 or y  > 5) and z > 8
print(result3)
#Step 1: (True or False) = True
#Step 2: True and True = True
# Out:
# True
# True
# True

# %%
# Practical use: avoid division by zero
divisor = 0
if divisor != 0 and (100/ divisor >5):
    print('Large quotient')     #Safe - never divides by 0!

# %%
#Traditional if/else:
score = 85
if score >= 60:
    result = 'Pass'
else: 
    result = 'Fail'

result = 'Pass' if score >= 60 else 'Fail'
print(result)

scores = [85, 42, 91, 55]
labels = ['Pass' if s >= 60 else 'Fail' for s in scores]
print(labels)
# Out:
# Pass
# ['Pass', 'Fail', 'Pass', 'Fail']

# %%
x = 8
if x > 5:
    if x > 10:
        print('big')
    else:
        print('medium')
else:
    print('small')
# Out:
# medium

# %%
a = True
b = False
if a and b:
    print('both')
elif a or b:
    print('one')
else:
    print('none')
# Out:
# one

# %%
n = 15
print('fizz' if n%3==0 else n, 'buzz' if n%5==0 else'')
# Out:
# fizz buzz
